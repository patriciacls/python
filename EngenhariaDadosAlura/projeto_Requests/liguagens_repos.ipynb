# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# url que fez a requisiçao

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %% [markdown]
# traz conteudo em string

# %%
r.text
# Out:
# '[{"id":"42707737485","type":"WatchEvent","actor":{"id":23123069,"login":"Leonidas-Li","display_login":"Leonidas-Li","gravatar_id":"","url":"https://api.github.com/users/Leonidas-Li","avatar_url":"https://avatars.githubusercontent.com/u/23123069?"},"repo":{"id":597451333,"name":"lucinhu/bili_you","url":"https://api.github.com/repos/lucinhu/bili_you"},"payload":{"action":"started"},"public":true,"created_at":"2024-10-10T00:22:52Z"},{"id":"42707737483","type":"DeleteEvent","actor":{"id":5514175,"login":"mattkrick","display_login":"mattkrick","gravatar_id":"","url":"https://api.github.com/users/mattkrick","avatar_url":"https://avatars.githubusercontent.com/u/5514175?"},"repo":{"id":48384473,"name":"ParabolInc/parabol","url":"https://api.github.com/repos/ParabolInc/parabol"},"payload":{"ref":"chore/TeamInvitation-phase2","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2024-10-10T00:22:52Z","org":{"id":14169569,"login":"ParabolInc","gravatar_id":"","url":"https://api
# ...

# %% [markdown]
# trazer em json

# %%
r.json()
# Out:
# [{'id': '42707737485',
#   'type': 'WatchEvent',
#   'actor': {'id': 23123069,
#    'login': 'Leonidas-Li',
#    'display_login': 'Leonidas-Li',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Leonidas-Li',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23123069?'},
#   'repo': {'id': 597451333,
#    'name': 'lucinhu/bili_you',
#    'url': 'https://api.github.com/repos/lucinhu/bili_you'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-10-10T00:22:52Z'},
#  {'id': '42707737483',
#   'type': 'DeleteEvent',
#   'actor': {'id': 5514175,
#    'login': 'mattkrick',
#    'display_login': 'mattkrick',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mattkrick',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5514175?'},
#   'repo': {'id': 48384473,
#    'name': 'ParabolInc/parabol',
#    'url': 'https://api.github.com/repos/ParabolInc/parabol'},
# ...

# %% [markdown]
# endpoints: alterar a url pra ter acesso as informaçoes

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# exercicio

# %%
e = requests.get( 'https://api.github.com/users/patriciacls')

# %%
e.status_code
# Out:
# 200

# %%
e.url
# Out:
# 'https://api.github.com/users/patriciacls'

# %%
e.json()
# Out:
# {'login': 'patriciacls',
#  'id': 99606147,
#  'node_id': 'U_kgDOBe_egw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/99606147?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/patriciacls',
#  'html_url': 'https://github.com/patriciacls',
#  'followers_url': 'https://api.github.com/users/patriciacls/followers',
#  'following_url': 'https://api.github.com/users/patriciacls/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/patriciacls/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/patriciacls/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/patriciacls/subscriptions',
#  'organizations_url': 'https://api.github.com/users/patriciacls/orgs',
#  'repos_url': 'https://api.github.com/users/patriciacls/repos',
#  'events_url': 'https://api.github.com/users/patriciacls/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/patriciacls/received_events',
#  'type': 'User',
# ...

# %%
e.json()['name']
# Out:
# 'Patricia Correia de Lima Santos'

# %%
e.json()['login']
# Out:
# 'patriciacls'

# %%
e.json()['public_gists']
# Out:
# 0

# %%
e.json()['created_at']
# Out:
# '2022-02-13T15:57:18Z'
